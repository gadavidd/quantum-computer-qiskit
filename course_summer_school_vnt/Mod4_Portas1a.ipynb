# %% [markdown]
# #Portas lógicas quânticas de 1 qubit

# %%
# !pip install qiskit[visualization]==1.2.2
# !pip install qiskit_aer
# !pip install qiskit_ibm_runtime
# !pip install matplotlib

# %%
import qiskit
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from numpy import pi
from math import sqrt
import qiskit.quantum_info as qi
from qiskit.visualization import plot_histogram

# %% [markdown]
# ##A representação mais geral para um qubit, é um vetor |ψ> definido no espaço de Hilbert
#
# Nesse exemplo o qubit já foi criado como uma superposição uniforme dos dois estados básicos |0> e |1>.

# %%
q = QuantumRegister(1, 'q')
circuito = QuantumCircuit(1)

α = 1/sqrt(2)
β = 1/sqrt(2)

ψ = [α, β]
circuito.initialize(ψ, q[0])

circuito.draw('mpl')

# %%
ψ = qi.Statevector(circuito)
ψ
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
probs = ψ.probabilities()
print(probs)
# Out:
# [0.5 0.5]

# %%
counts = ψ.sample_counts(shots=1024)
print(counts)
# Out:
# {'0': 525, '1': 499}

# %%
plot_histogram(counts)

# %%
ψ.draw('bloch')

# %% [markdown]
# # Uma outra forma de inicializar o estado mais geral de 1 qubit
#
# Esse é o caso mais simples e mais usual para inicializar o qubit. Perceba que o vetor tem o sentido apontado para o estado |0>, ou seja, isso indica que o qubit não está num estado de superposição.

# %%
qc1 = QuantumCircuit(1)
qc1.draw('mpl')

# %%
ψ = qi.Statevector(qc1)
ψ
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))

# %%
probs = ψ.probabilities()
print(probs)
# Out:
# [1. 0.]

# %%
counts = ψ.sample_counts(shots=1024)
print(counts)
# Out:
# {'0': 1024}

# %%
plot_histogram(counts)

# %%
ψ.draw('bloch')

# %% [markdown]
# #Aplicando as portas X, Y e Z
#
# Agora que já sabemos inicializar os qubits, podemos aplicar as devidas portas X, Y e Z. Vamos aplicar cada uma individualmente e enteder o comportamento delas.

# %% [markdown]
# **Atuando com a Porta Pauli-X no circuito "qc2"**
#
# Essa porta equivale à rotação em torno do eixo x na esfera de Bloch por π radianos.
#
# Portanto, X|0> = |1>  e  X|1> = |0>
#
# OBS: O circuito qc2 é o mesmo inicial qc1.

# %%
qc2 = QuantumCircuit(1)
qc2.x(0)
qc2.draw('mpl')

# %%
ψ = qi.Statevector(qc2)
ψ
# Out:
# Statevector([0.+0.j, 1.+0.j],
#             dims=(2,))

# %%
probs = ψ.probabilities()
print(probs)
# Out:
# [0. 1.]

# %%
counts = ψ.sample_counts(shots=1024)
print(counts)
# Out:
# {'1': 1024}

# %%
plot_histogram(counts)

# %%
ψ.draw('bloch')

# %% [markdown]
# **Atuando com a Porta de Pauli-X no Circuito "qc3"**

# %%
qc3 = circuito
qc3.x(0)
qc3.draw('mpl')

# %%
ψ = qi.Statevector(qc3)
ψ
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
probs = ψ.probabilities()
print(probs)
# Out:
# [0.5 0.5]

# %%
counts = ψ.sample_counts(shots=1024)
print(counts)
# Out:
# {'0': 506, '1': 518}

# %%
plot_histogram(counts)

# %%
ψ.draw('bloch')

# %% [markdown]
# **Atuando com a Porta Pauli-Y no circuito "qc4"**
#
# Essa porta equivale à rotação em torno do eixo y na esfera de Bloch por π radianos.
#
# Portanto, Y |0> = i|1>  e  Y |1> = -i|0>
#
# OBS: O circuito qc4 é o mesmo inicial qc1.

# %%
qc4 = QuantumCircuit(1)
qc4.y(0)
qc4.draw('mpl')

# %%
ψ = qi.Statevector(qc4)
ψ
# Out:
# Statevector([0.+0.j, 0.+1.j],
#             dims=(2,))

# %%
probs = ψ.probabilities()
print(probs)
# Out:
# [0. 1.]

# %%
counts = ψ.sample_counts(shots=1024)
print(counts)
# Out:
# {'1': 1024}

# %%
plot_histogram(counts)

# %%
ψ.draw('bloch')

# %% [markdown]
# **Atuando com a Porta de Pauli-Y no Circuito "circuito2"**
#
# Inicialmente criamos o cicuito2 para depois atuar com porta Y.

# %%
circuito2 = QuantumCircuit(1)

α = 1/sqrt(2)
β = 1/sqrt(2)

ψ = [α, β]
circuito2.initialize(ψ, q[0])

circuito2.draw('mpl')

# %%
ψ = qi.Statevector(circuito2)
ψ
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
ψ.draw('bloch')

# %% [markdown]
# Agora atua com a Porta Pauli-Y

# %%
qc5 = circuito2
qc5.y(0)
qc5.draw('mpl')

# %%
ψ = qi.Statevector(qc5)
ψ
# Out:
# Statevector([0.-0.70710678j, 0.+0.70710678j],
#             dims=(2,))

# %%
probs = ψ.probabilities()
print(probs)
# Out:
# [0.5 0.5]

# %%
counts = ψ.sample_counts(shots=1024)
print(counts)
# Out:
# {'0': 523, '1': 501}

# %%
plot_histogram(counts)

# %%
ψ.draw('bloch')

# %% [markdown]
# **Atuando com a Porta Pauli-Z no circuito "qc6"**
#
# Essa porta equivale à rotação em torno do eixo z na esfera de Bloch. Ela inverte a fase.
#
# Portanto, Z |1> = -|1> muda fase e Z|0> = |0> faz nada.
#
# OBS: O circuito qc6 é o mesmo inicial qc1.

# %%
qc6 = QuantumCircuit(1)
qc6.z(0)
qc6.draw('mpl')

# %%
ψ = qi.Statevector(qc6)
ψ
# Out:
# Statevector([1.+0.j, 0.+0.j],
#             dims=(2,))

# %%
probs = ψ.probabilities()
print(probs)
# Out:
# [1. 0.]

# %%
counts = ψ.sample_counts(shots=1024)
print(counts)
# Out:
# {'0': 1024}

# %%
plot_histogram(counts)

# %%
ψ.draw('bloch')

# %% [markdown]
# **Atuando com a Porta de Pauli-Z no Circuito "circuito3"**
#
# Inicialmente criamos o cicuito3 para depois atuar com porta Z.

# %%
circuito3 = QuantumCircuit(1)

α = 1/sqrt(2)
β = 1/sqrt(2)

ψ = [α, β]
circuito3.initialize(ψ, q[0])

circuito3.draw('mpl')

# %%
ψ = qi.Statevector(circuito3)
ψ
# Out:
# Statevector([0.70710678+0.j, 0.70710678+0.j],
#             dims=(2,))

# %%
ψ.draw('bloch')

# %% [markdown]
# Agora atua com a Porta Pauli-Z

# %%
qc7 = circuito3
qc7.z(0)
qc7.draw('mpl')

# %%
ψ = qi.Statevector(qc7)
ψ
# Out:
# Statevector([ 0.70710678+0.j, -0.70710678+0.j],
#             dims=(2,))

# %%
ψ.draw('bloch')
